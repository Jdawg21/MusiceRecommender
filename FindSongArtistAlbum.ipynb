# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)
song_df = pd.read_csv('datasets/spotify_songs.csv') 

song_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  0017A6SJgTbfQVU2EtsPNo                                           Pangarap
# 1  004s3t0ONYlzxII9PLgU6z                                       I Feel Alive
# 2  00chLpzhgVjxs1zKC9UScL                                             Poison
# 3  00cqd6ZsSkLZqGMlQCR0Zo  Baby It's Cold Outside (feat. Christina Aguilera)
# 4  00emjlCv9azBN0fzuuyLqy                                         Dumb Litty
#
#       track_artist                                             lyrics  \
# 0  Barbie's Cradle  Minsan pa Nang ako'y napalingon Hindi ko alam ...
# 1    Steady Rollin  The trees, are singing in the wind The sky blu...
# 2   Bell Biv DeVoe  NA Yeah, Spyderman and Freeze in full effect U...
# 3      CeeLo Green  I really can't stay Baby it's cold outside I'v...
# 4             KARD  Get up out of my business You don't keep me fr...
#
#    track_popularity          track_album_id  \
# 0                41  1srJQ0njEQgd8w4XSqI4JQ
# 1                28  3z04Lb9Dsilqw68SHt6jLB
# 2                 0  6oZ6brjB8x3GoeSYdwJdPc
# 3                41  3ssspRe42CXkhPxdc12xcp
# 4                65  7h5X3xhh3peIK9Y0qI5hbK
#
#                        track_album_name track_album_release_date  \
# 0                                  Trip               2001-01-01
# 1                           Love & Loss               2017-11-21
# 2                                  Gold               2005-01-01
# 3                  CeeLo's Magic Moment               2012-10-29
# 4  KARD 2nd Digital Single ‘Dumb Litty’               2019-09-22
#
#                                        playlist_name             playlist_id  \
# 0                                 Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt
# 1                                  Hard Rock Workout  3YouF0u7waJnolytf9JCXf
# 2  Back in the day - R&B, New Jack Swing, Swingbe...  3a9y4eeCJRmG9p4YKfqYIx
# 3                                     Christmas Soul  6FZYc2BvF7tColxO8PBShV
# 4                                  K-Party Dance Mix  37i9dQZF1DX4RDXswvP6Mj
#
#   playlist_genre playlist_subgenre  danceability  energy  key  loudness  mode  \
# 0           rock      classic rock         0.682   0.401    2   -10.068     1
# 1           rock         hard rock         0.303   0.880    9    -4.739     1
# 2            r&b    new jack swing         0.845   0.652    6    -7.504     0
# 3            r&b          neo soul         0.425   0.378    5    -5.819     0
# 4            pop         dance pop         0.760   0.887    9    -1.993     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0236       0.27900           0.01170    0.0887    0.566   97.091
# 1       0.0442       0.01170           0.00994    0.3470    0.404  135.225
# 2       0.2160       0.00432           0.00723    0.4890    0.650  111.904
# 3       0.0341       0.68900           0.00000    0.0664    0.405  118.593
# 4       0.0409       0.03700           0.00000    0.1380    0.240  130.018
#
#    duration_ms language
# 0       235440       tl
# 1       373512       en
# 2       262467       en
# 3       243067       en
# 4       193160       en

# %%
song_data = song_df[['track_name', 'track_artist', 'lyrics',
      'track_album_name',
       'playlist_name',  'playlist_genre', 'playlist_subgenre',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
        'language']]

# %%
#song_data[song_data['language'].isin(['en','es'])]

# %%
song_data = song_data[song_data['language'].isin(['en','es'])]
song_data.reset_index(inplace=True)
song_data.shape
# Out:
# (17110, 20)

# %%
song_data.drop('index',axis=1,inplace=True)
song_data.head()
# Out:
#                                           track_name    track_artist  \
# 0                                       I Feel Alive   Steady Rollin
# 1                                             Poison  Bell Biv DeVoe
# 2  Baby It's Cold Outside (feat. Christina Aguilera)     CeeLo Green
# 3                                         Dumb Litty            KARD
# 4                                            Soldier        James TW
#
#                                               lyrics  \
# 0  The trees, are singing in the wind The sky blu...
# 1  NA Yeah, Spyderman and Freeze in full effect U...
# 2  I really can't stay Baby it's cold outside I'v...
# 3  Get up out of my business You don't keep me fr...
# 4  Hold your breath, don't look down, keep trying...
#
#                        track_album_name  \
# 0                           Love & Loss
# 1                                  Gold
# 2                  CeeLo's Magic Moment
# 3  KARD 2nd Digital Single ‘Dumb Litty’
# 4                              Chapters
#
#                                        playlist_name playlist_genre  \
# 0                                  Hard Rock Workout           rock
# 1  Back in the day - R&B, New Jack Swing, Swingbe...            r&b
# 2                                     Christmas Soul            r&b
# 3                                  K-Party Dance Mix            pop
# 4                                 urban contemporary            r&b
#
#     playlist_subgenre  danceability  energy  key  loudness  mode  speechiness  \
# 0           hard rock         0.303   0.880    9    -4.739     1       0.0442
# 1      new jack swing         0.845   0.652    6    -7.504     0       0.2160
# 2            neo soul         0.425   0.378    5    -5.819     0       0.0341
# 3           dance pop         0.760   0.887    9    -1.993     1       0.0409
# 4  urban contemporary         0.496   0.639    6    -6.157     1       0.0550
#
#    acousticness  instrumentalness  liveness  valence    tempo language
# 0       0.01170           0.00994    0.3470    0.404  135.225       en
# 1       0.00432           0.00723    0.4890    0.650  111.904       en
# 2       0.68900           0.00000    0.0664    0.405  118.593       en
# 3       0.03700           0.00000    0.1380    0.240  130.018       en
# 4       0.28000           0.00000    0.0975    0.305  147.764       en

# %%
song_data['playlist_name'] = song_data['playlist_name'].str.lower()
song_data['track_name'] = song_data['track_name'].str.lower()
song_data['track_artist'] = song_data['track_artist'].str.lower()
song_data['track_album_name'] = song_data['track_album_name'].str.lower()
song_data['lyrics'] = song_data['lyrics'].str.lower()
song_data['playlist_genre'] = song_data['playlist_genre'].str.lower()
song_data['playlist_subgenre'] = song_data['playlist_subgenre'].str.lower()

# %%
song_data = song_data.drop_duplicates(subset=['track_name','track_artist'], keep='first')
song_data.reset_index(inplace=True)
song_data.drop('index',axis=1,inplace=True)

# %% [markdown]
# # find artist of song

# %%
songgname = "mambeado"
songgname = songgname.lower()
songg = song_data[song_data['track_name'] == songgname]
#songg['artist_name'].unique().tolist()[0]
songg
# Out:
#       track_name track_artist  \
# 11661   mambeado    onda vaga
#
#                                                   lyrics   track_album_name  \
# 11661  letra de "mambeado"que lindo que es estar en l...  fuerte y caliente
#
#         playlist_name playlist_genre playlist_subgenre  danceability  energy  \
# 11661  vibra tropical          latin          tropical         0.724   0.783
#
#        key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 11661    0    -4.755     1       0.0414         0.766               0.0
#
#        liveness  valence   tempo language
# 11661     0.256    0.956  87.515       es

# %% [markdown]
# # find album of song

# %%
songgname = 'poison'
songgname = songgname.lower()
songg = song_data[song_data['track_name'] == songgname]
#songg['album_names'].unique().tolist()
songg
# Out:
#       track_name    track_artist  \
# 1         poison  bell biv devoe
# 3116      poison    alice cooper
# 11188     poison    brent faiyaz
# 13899     poison        rita ora
#
#                                                   lyrics  \
# 1      na yeah, spyderman and freeze in full effect u...
# 3116   your cruel device your blood, like ice one loo...
# 11188  i feel like there's no such thing as a relatio...
# 13899  i could have beer for breakfast my sanity for ...
#
#              track_album_name  \
# 1                        gold
# 3116   alice cooper classicks
# 11188                  poison
# 13899                  poison
#
#                                            playlist_name playlist_genre  \
# 1      back in the day - r&b, new jack swing, swingbe...            r&b
# 3116                                  80s / classic rock           rock
# 11188                                 urban contemporary            r&b
# 13899                                      post teen pop            pop
#
#         playlist_subgenre  danceability  energy  key  loudness  mode  \
# 1          new jack swing         0.845   0.652    6    -7.504     0
# 3116         classic rock         0.300   0.894    2    -7.786     0
# 11188  urban contemporary         0.689   0.394    2   -10.102     0
# 13899       post-teen pop         0.579   0.738   10    -5.711     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 1           0.2160       0.00432          0.007230    0.4890    0.650
# 3116        0.1090       0.05150          0.000333    0.1250    0.268
# 11188       0.0650       0.71100          0.000905    0.0859    0.382
# 13899       0.0542       0.08210          0.000002    0.2320    0.431
#
#          tempo language
# 1      111.904       en
# 3116   118.631       en
# 11188  117.489       en
# 13899  124.023       en

# %% [markdown]
# # find songs of artist

# %%
artistname = "lauv"
artistname = artistname.lower()
artist = song_data[song_data['track_artist'] == artistname]
artist['track_name'].unique().tolist()
#artist
# Out:
# ['feelings',
#  'tattoos together',
#  'i like me better - ryan riback remix',
#  'i like me better',
#  'chasing fire',
#  "there's no way (feat. julia michaels)",
#  "fuck, i'm lonely (with anne-marie) - from “13 reasons why: season 3”",
#  'the other - dallask remix',
#  'enemies',
#  "there's no way (feat. julia michaels) - alle farben remix",
#  'the story never ends',
#  'changes',
#  "i'm so tired...",
#  'reforget',
#  'sims']

# %% [markdown]
# # dealing with genres (not complete, we wont use this most probably so skip it)

# %%
song_data[song_data['playlist_genre'] == 'pop']
# Out:
#                                          track_name        track_artist  \
# 3                                        dumb litty                kard
# 9                                         limestone  magic city hippies
# 15                   you don't know me - radio edit           jax jones
# 18     stand out - from "how to build a better boy"   sabrina carpenter
# 23                                    juke box hero           foreigner
# ...                                             ...                 ...
# 15204                     the riddle (original mix)     gigi d'agostino
# 15205                           singing in the rain         simple plan
# 15206                                       the end            daughter
# 15208                                       sisters            leoniden
# 15211                                    cold water         major lazer
#
#                                                   lyrics  \
# 3      get up out of my business you don't keep me fr...
# 9      how many friends are you gonna set on fire? ho...
# 15     ooh, na-na, yeah don't act like you know me, l...
# 18     don't sweat all the little things just keep yo...
# 23     standing in the rain, with his head hung low c...
# ...                                                  ...
# 15204  i got two strong arms blessings of babylon tim...
# 15205  i'm reading through the sunday paper and it's ...
# 15206  this is the end, this is the end you wait to f...
# 15208  this is for your sisters covering the picture ...
# 15211  everybody gets high sometimes, you know what e...
#
#                                    track_album_name  \
# 3              kard 2nd digital single ‘dumb litty’
# 9                                  hippie castle ep
# 15                                you don't know me
# 18     stand out (from "how to build a better boy")
# 23                                     4 (expanded)
# ...                                             ...
# 15204                                    the riddle
# 15205                           singing in the rain
# 15206                                       the end
# 15208                                      leoniden
# 15211                                    cold water
#
#                                            playlist_name playlist_genre  \
# 3                                      k-party dance mix            pop
# 9                                        indie poptimism            pop
# 15                                         ballare - رقص            pop
# 18                                     🤩🤪post teen pop🤪🤩            pop
# 23                        dr. q's prescription playlist💊            pop
# ...                                                  ...            ...
# 15204                                     90s dance hits            pop
# 15205  random playlist that can't decide its genre so...            pop
# 15206                               deep-deep bubble pop            pop
# 15208                               indie/jazz poptimism            pop
# 15211                                    electropop 2020            pop
#
#       playlist_subgenre  danceability  energy  key  loudness  mode  \
# 3             dance pop         0.760   0.887    9    -1.993     1
# 9       indie poptimism         0.706   0.457    4    -9.359     1
# 15        post-teen pop         0.876   0.669   11    -6.054     0
# 18        post-teen pop         0.414   0.806    7    -2.892     1
# 23        post-teen pop         0.357   0.653    9    -5.554     1
# ...                 ...           ...     ...  ...       ...   ...
# 15204         dance pop         0.744   0.868    6    -6.844     0
# 15205   indie poptimism         0.617   0.733    9    -3.760     1
# 15206   indie poptimism         0.463   0.688    9    -8.127     1
# 15208   indie poptimism         0.710   0.736    5    -4.380     0
# 15211        electropop         0.608   0.798    6    -5.092     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 3           0.0409       0.03700          0.000000    0.1380    0.240
# 9           0.0383       0.28200          0.008490    0.0614    0.723
# 15          0.1380       0.16300          0.000000    0.1850    0.682
# 18          0.0665       0.00792          0.000093    0.0488    0.770
# 23          0.0654       0.08280          0.000000    0.0844    0.522
# ...            ...           ...               ...       ...      ...
# 15204       0.0367       0.02420          0.002110    0.0753    0.851
# 15205       0.0424       0.02760          0.000000    0.0962    0.719
# 15206       0.0438       0.87300          0.004560    0.0666    0.200
# 15208       0.0347       0.10700          0.000006    0.0680    0.746
# 15211       0.0432       0.07360          0.000000    0.1560    0.501
#
#          tempo language
# 3      130.018       en
# 9       78.014       en
# 15     124.007       en
# 18      96.044       en
# 23     176.647       en
# ...        ...      ...
# 15204  126.990       en
# 15205  149.019       en
# 15206  128.986       en
# 15208  130.985       en
# 15211   92.943       en
#
# [3411 rows x 19 columns]
